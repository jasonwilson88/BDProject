# %%
import numpy as np
import pandas as pd
import seaborn as sn
sn.set_style("darkgrid")

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
tweetsByHour = pd.read_json(path_or_buf='/home/jack/BDProject/Part2/three/tweetsByHour2/byHour.json', lines=True)

# %%
tweetsByHour
# Out:
#     countt                          timee
# 0      544  2018-09-11T14:00:00.000-05:00
# 1     5643  2018-09-11T15:00:00.000-05:00
# 2     8002  2018-09-13T17:00:00.000-05:00
# 3     5153  2018-09-13T18:00:00.000-05:00
# 4     8537  2018-09-14T11:00:00.000-05:00
# 5    14017  2018-09-14T12:00:00.000-05:00
# 6     9907  2018-09-14T13:00:00.000-05:00
# 7    12132  2018-09-14T14:00:00.000-05:00
# 8    11404  2018-09-14T15:00:00.000-05:00
# 9    10050  2018-09-14T16:00:00.000-05:00
# 10    8526  2018-09-14T17:00:00.000-05:00
# 11    7613  2018-09-14T18:00:00.000-05:00
# 12    1408  2018-09-14T19:00:00.000-05:00

# %%
g = sn.lineplot(x='timee', y='countt', data=tweetsByHour)

# %%
g = sn.lineplot(x='timee', y='countt', data=tweetsByHour).set_xticklabels(g.get_xticklabels(), rotation=90)
